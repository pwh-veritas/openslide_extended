# %%
# !pip install -e /mnt/d/curtis_projects/openslide_extended

# %%
from openslide_extended.openslide_extended import OpenSlideExtended

slide = "/mnt/x/veritas_volume/slide_database/22S04089-I-8-F AE13.svs"
osr = OpenSlideExtended(slide)
osr.get_thumbnail()
# Out:
# <PIL.Image.Image image mode=RGB size=512x295>
